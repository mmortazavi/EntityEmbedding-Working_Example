# %% [markdown]
# # Entity Embedding - Working Example " House Prices"
#
# **The purpose of this notebook is to demonstrate  the practical implementation of the so-called Entity Embedding  for Encoding Categorical Features for Training a Neural Network.**

# %% [markdown]
# ## Loading Libraries

# %%
import os 
import matplotlib.pylab as plt
import pandas as pd

import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import metrics, linear_model
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential,Model
from keras.models import Model as KerasModel
from keras.layers import Input, Dense, Activation, Reshape
from keras.layers import Concatenate, Dropout
from keras.layers.embeddings import Embedding
from keras.callbacks import ModelCheckpoint
from keras.utils import plot_model

plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ##  The Ames Iowa Housing Data.

# %%
url = 'http://www.amstat.org/publications/jse/v19n3/decock/AmesHousing.xls'
# Load the file into a Pandas DataFrame
data_df = pd.read_excel(url)
print('DataFrame size:', data_df.shape)
# Out:
# DataFrame size: (2930, 82)

# %%
data_df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             6             5
# 1       Feedr        Norm      1Fam      1Story             5             6
# 2        Norm        Norm      1Fam      1Story             6             6
# 3        Norm        Norm      1Fam      1Story             7             5
# 4        Norm        Norm      1Fam      2Story             5             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st    ...      \
# 0        1960            1960        Hip   CompShg      BrkFace    ...
# 1        1961            1961      Gable   CompShg      VinylSd    ...
# 2        1958            1958        Hip   CompShg      Wd Sdng    ...
# 3        1968            1968        Hip   CompShg      BrkFace    ...
# 4        1997            1998      Gable   CompShg      VinylSd    ...
#
#   Fireplaces Fireplace Qu  Garage Type Garage Yr Blt Garage Finish  \
# 0          2           Gd       Attchd        1960.0           Fin
# 1          0          NaN       Attchd        1961.0           Unf
# 2          0          NaN       Attchd        1958.0           Unf
# 3          2           TA       Attchd        1968.0           Fin
# 4          1           TA       Attchd        1997.0           Fin
#
#   Garage Cars Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0         2.0       528.0          TA          TA           P           210
# 1         1.0       730.0          TA          TA           Y           140
# 2         1.0       312.0          TA          TA           Y           393
# 3         2.0       522.0          TA          TA           Y             0
# 4         2.0       482.0          TA          TA           Y           212
#
#   Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch Pool Area Pool QC  \
# 0            62               0           0             0         0     NaN
# 1             0               0           0           120         0     NaN
# 2            36               0           0             0         0     NaN
# 3             0               0           0             0         0     NaN
# 4            34               0           0             0         0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 0    NaN          NaN         0        5     2010        WD           Normal
# 1  MnPrv          NaN         0        6     2010        WD           Normal
# 2    NaN         Gar2     12500        6     2010        WD           Normal
# 3    NaN          NaN         0        4     2010        WD           Normal
# 4  MnPrv          NaN         0        3     2010        WD           Normal
#
#    SalePrice
# 0     215000
# 1     105000
# 2     172000
# 3     244000
# 4     189900
#
# [5 rows x 82 columns]

# %% [markdown]
# ## Sub-Feature Space

# %%
# For same of demonstration, the following features are selected. 
features = ['Neighborhood','Bldg Type','Year Built','Roof Matl','Sale Condition','Sale Type','House Style','Gr Liv Area']

# The aim is to predcit sale prices.
target = ['SalePrice']
data_df=data_df[features + target]
data_df['Year Built']= data_df['Year Built'].astype('object')

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### *  ** Train/Val/Test Split**

# %%
X_train, y_train = data_df.iloc[:2000][features], data_df.iloc[:2000][target]
X_val, y_val = data_df.iloc[2000:2500][features], data_df.iloc[2000:2500][target]
X_test = data_df.iloc[2500:][features]

# %% [markdown]
# ### *  ** Data Transformations**

# %%
scalar=StandardScaler()
scalar.fit(X_train['Gr Liv Area'].reshape(-1, 1))
X_train['Gr Liv Area']=scalar.transform(X_train['Gr Liv Area'].reshape(-1, 1)) 
X_val['Gr Liv Area']=scalar.transform(X_val['Gr Liv Area'].reshape(-1, 1)) 

scalar.fit(y_train)
y_train=scalar.transform(y_train)
y_val=scalar.transform(y_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5d60422c904b> in <module>()
#       1 scalar=StandardScaler()
# ----> 2 scalar.fit(X_train['Gr Liv Area'].reshape(-1, 1))
#       3 X_train['Gr Liv Area']=scalar.transform(X_train['Gr Liv Area'].reshape(-1, 1))
#       4 X_val['Gr Liv Area']=scalar.transform(X_val['Gr Liv Area'].reshape(-1, 1))
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %% [markdown]
# ### *  ** Check for Mising Values**

# %%
missing_df = data_df[features + target].isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(data_df[features + target].shape[0]-missing_df['missing values'])/data_df[features + target].shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#          variable  missing values  filling factor (%)
# 0    Neighborhood               0               100.0
# 1       Bldg Type               0               100.0
# 2      Year Built               0               100.0
# 3       Roof Matl               0               100.0
# 4  Sale Condition               0               100.0
# 5       Sale Type               0               100.0
# 6     House Style               0               100.0
# 7     Gr Liv Area               0               100.0
# 8       SalePrice               0               100.0

# %% [markdown]
# ## *  **  Categorical Features Embedding Preparation**

# %% [markdown]
# ### *  ** Categorical Features and  Cardinality**

# %%
embed_cols=[i for i in X_train.select_dtypes(include=['object'])]

for i in embed_cols:
    print(i,data_df[i].nunique())
# Out:
# Neighborhood 28
# Bldg Type 5
# Year Built 118
# Roof Matl 8
# Sale Condition 6
# Sale Type 10
# House Style 8

# %% [markdown]
# ### *  ** Categorical Features To List Format**
# One need to convert data to list format to match the network structure.
#
# The following function takes the list of categorical features, and prepare such lists for the NN input.

# %%
embed_cols=[i for i in X_train.select_dtypes(include=['object'])]

#converting data to list format to match the network structure
def preproc(X_train, X_val, X_test):

    input_list_train = []
    input_list_val = []
    input_list_test = []
    
    #the cols to be embedded: rescaling to range [0, # values)
    for c in embed_cols:
        raw_vals = np.unique(X_train[c])
        val_map = {}
        for i in range(len(raw_vals)):
            val_map[raw_vals[i]] = i       
        input_list_train.append(X_train[c].map(val_map).values)
        input_list_val.append(X_val[c].map(val_map).fillna(0).values)
        input_list_test.append(X_test[c].map(val_map).fillna(0).values)
     
    #the rest of the columns
    other_cols = [c for c in X_train.columns if (not c in embed_cols)]
    input_list_train.append(X_train[other_cols].values)
    input_list_val.append(X_val[other_cols].values)
    input_list_test.append(X_test[other_cols].values)
    
    return input_list_train, input_list_val, input_list_test

# %%
X_train.head()
# Out:
#   Neighborhood Bldg Type Year Built Roof Matl Sale Condition Sale Type  \
# 0        NAmes      1Fam       1960   CompShg         Normal       WD
# 1        NAmes      1Fam       1961   CompShg         Normal       WD
# 2        NAmes      1Fam       1958   CompShg         Normal       WD
# 3        NAmes      1Fam       1968   CompShg         Normal       WD
# 4      Gilbert      1Fam       1997   CompShg         Normal       WD
#
#   House Style  Gr Liv Area
# 0      1Story     0.315074
# 1      1Story    -1.224202
# 2      1Story    -0.347220
# 3      1Story     1.234589
# 4      2Story     0.260389

# %% [markdown]
# ### *  ** Embedding Dimension - Hyperparamter**
# The choice of embedding dimension is optional, essentially it is a hyperparamter that one need to choose beforehand and investigate. One rule of thumb is to choose half of the cardinality of the categorical feature if that is is up to 50 in length.

# %%
for categorical_var in X_train.select_dtypes(include=['object']):
    
    cat_emb_name= categorical_var.replace(" ", "")+'_Embedding'
  
      no_of_unique_cat  = X_train[categorical_var].nunique()
      embedding_size = int(min(np.ceil((no_of_unique_cat)/2), 50 ))
      vocab  = no_of_unique_cat+1
  
      print('Categorica Variable:', categorical_var,
        'Unique Categories:', no_of_unique_cat,
        'Embedding Size:', embedding_size,
        'Vocab:', vocab)
# Out:
# Categorica Variable: Neighborhood Unique Categories: 26 Embedding Size: 13 Vocab: 27
# Categorica Variable: Bldg Type Unique Categories: 5 Embedding Size: 3 Vocab: 6
# Categorica Variable: Year Built Unique Categories: 116 Embedding Size: 50 Vocab: 117
# Categorica Variable: Roof Matl Unique Categories: 7 Embedding Size: 4 Vocab: 8
# Categorica Variable: Sale Condition Unique Categories: 6 Embedding Size: 3 Vocab: 7
# Categorica Variable: Sale Type Unique Categories: 9 Embedding Size: 5 Vocab: 10
# Categorica Variable: House Style Unique Categories: 8 Embedding Size: 4 Vocab: 9

# %% [markdown]
# ### *  ** Proper Naming of Categorical Features for Labelling NN Layers**

# %%
for categorical_var in X_train.select_dtypes(include=['object']):
    
    input_name= 'Input_' + categorical_var.replace(" ", "")
    print(input_name)
# Out:
# Input_Neighborhood
# Input_BldgType
# Input_YearBuilt
# Input_RoofMatl
# Input_SaleCondition
# Input_SaleType
# Input_HouseStyle

# %% [markdown]
# ## *  ** Build Neural Network**

# %% [markdown]
# ### *  ** Putting it Altogether**
# Here we basically make the embeding layers one at a time and append, and at the end we concatenate it together with the numerical features.

# %%
input_models=[]
output_embeddings=[]
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

for categorical_var in X_train.select_dtypes(include=['object']):
  
  #Name of the categorical variable that will be used in the Keras Embedding layer
  cat_emb_name= categorical_var.replace(" ", "")+'_Embedding'
  
  # Define the embedding_size
  no_of_unique_cat  = X_train[categorical_var].nunique()
  embedding_size = int(min(np.ceil((no_of_unique_cat)/2), 50 ))
  vocab  = no_of_unique_cat+1
  
  #One Embedding Layer for each categorical variable
  input_model = Input(shape=(1,))
  output_model = Embedding(vocab, embedding_size, name=cat_emb_name)(input_model)
  output_model = Reshape(target_shape=(embedding_size,))(output_model)    
  
  #Appending all the categorical inputs
  input_models.append(input_model)
  
  #Appending all the embeddings
  output_embeddings.append(output_model)
  
#Other non-categorical data columns (numerical). 
#I define single another network for the other columns and add them to our models list.
input_numeric = Input(shape=(len(X_train.select_dtypes(include=numerics).columns.tolist()),))
embedding_numeric = Dense(128)(input_numeric) 
input_models.append(input_numeric)
output_embeddings.append(embedding_numeric)

#At the end we concatenate altogther and add other Dense layers
output = Concatenate()(output_embeddings)
output = Dense(1000, kernel_initializer="uniform")(output)
output = Activation('relu')(output)
output= Dropout(0.4)(output)
output = Dense(512, kernel_initializer="uniform")(output)
output = Activation('relu')(output)
output= Dropout(0.3)(output)
output = Dense(1, activation='sigmoid')(output)

model = Model(inputs=input_models, outputs=output)
model.compile(loss='mean_squared_error', optimizer='Adam',metrics=['mse','mape'])

# %% [markdown]
# ### *  ** The Network Architecture**

# %%
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')
from IPython.display import Image
Image(retina=True, filename='model.png')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_27 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_29 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_30 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# input_31 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# Neighborhood_Embedding (Embeddi (None, 1, 13)        351         input_25[0][0]
# __________________________________________________________________________________________________
# BldgType_Embedding (Embedding)  (None, 1, 3)         18          input_26[0][0]
# __________________________________________________________________________________________________
# YearBuilt_Embedding (Embedding) (None, 1, 50)        5850        input_27[0][0]
# __________________________________________________________________________________________________
# RoofMatl_Embedding (Embedding)  (None, 1, 4)         32          input_28[0][0]
# __________________________________________________________________________________________________
# SaleCondition_Embedding (Embedd (None, 1, 3)         21          input_29[0][0]
# __________________________________________________________________________________________________
# SaleType_Embedding (Embedding)  (None, 1, 5)         50          input_30[0][0]
# __________________________________________________________________________________________________
# HouseStyle_Embedding (Embedding (None, 1, 4)         36          input_31[0][0]
# __________________________________________________________________________________________________
# input_32 (InputLayer)           (None, 1)            0
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 13)           0           Neighborhood_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 3)            0           BldgType_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 50)           0           YearBuilt_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 4)            0           RoofMatl_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 3)            0           SaleCondition_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_27 (Reshape)            (None, 5)            0           SaleType_Embedding[0][0]
# __________________________________________________________________________________________________
# reshape_28 (Reshape)            (None, 4)            0           HouseStyle_Embedding[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          256         input_32[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 210)          0           reshape_22[0][0]
#                                                                  reshape_23[0][0]
#                                                                  reshape_24[0][0]
#                                                                  reshape_25[0][0]
#                                                                  reshape_26[0][0]
#                                                                  reshape_27[0][0]
#                                                                  reshape_28[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1000)         211000      concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 1000)         0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1000)         0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          512512      dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 512)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            513         dropout_2[0][0]
# ==================================================================================================
# Total params: 730,639
# Trainable params: 730,639
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### *  ** Training**

# %%
X_train_list,X_val_list,X_test_list = preproc(X_train,X_val, X_test)

# %%
history  =  model.fit(X_train_list,y_train,validation_data=(X_val_list,y_val) , epochs =  1000 , batch_size = 512, verbose= 2)
# Out:
# Train on 2000 samples, validate on 500 samples
# Epoch 1/1000
#  - 3s - loss: 1.1215 - mean_squared_error: 1.1215 - mean_absolute_percentage_error: 298.4222 - val_loss: 0.8739 - val_mean_squared_error: 0.8739 - val_mean_absolute_percentage_error: 271.7353
# Epoch 2/1000
#  - 0s - loss: 0.8407 - mean_squared_error: 0.8407 - mean_absolute_percentage_error: 252.5188 - val_loss: 0.7464 - val_mean_squared_error: 0.7464 - val_mean_absolute_percentage_error: 212.1898
# Epoch 3/1000
#  - 0s - loss: 0.7640 - mean_squared_error: 0.7640 - mean_absolute_percentage_error: 200.1515 - val_loss: 0.7301 - val_mean_squared_error: 0.7301 - val_mean_absolute_percentage_error: 169.4000
# Epoch 4/1000
#  - 0s - loss: 0.7334 - mean_squared_error: 0.7334 - mean_absolute_percentage_error: 169.3617 - val_loss: 0.7189 - val_mean_squared_error: 0.7189 - val_mean_absolute_percentage_error: 145.0171
# Epoch 5/1000
#  - 0s - loss: 0.7077 - mean_squared_error: 0.7077 - mean_absolute_percentage_error: 146.4570 - val_loss: 0.6990 - val_mean_squared_error: 0.6990 - val_mean_absolute_percentage_error: 131.1398
# Epoch 6/1000
#  - 0s - loss: 0.6729 - mean_squared_error: 0.6729 - mean_absolute_percentage_error: 124.5543 - val_loss: 0.6789 - val_mean_squared_error: 0.6789 - val_mean_absolute_percentage_error: 118.4418
# Epoch 7/1000
#  - 0s - loss: 0.6434 - mean_squared_error: 0.6434 - mean_absolute_percentage_error: 110.2854 - val_loss: 0.6603 - val_mean_squared_error: 0.6603 - val_mean_absolute_percentage_error: 119.4158
# Epoch 8/1000
#  - 0s - loss: 0.6215 - mean_squared_error: 0.6215 - mean_absolute_percentage_error: 103.6919 - val_loss: 0.6603 - val_mean_squared_error: 0.6603 - val_mean_absolute_percentage_error: 132.3274
# Epoch 9/1000
#  - 0s - loss: 0.6137 - mean_squared_error: 0.6137 - mean_absolute_percentage_error: 114.5908 - val_loss: 0.6484 - val_mean_squared_error: 0.6484 - val_mean_absolute_percentage_error: 131.3525
# Epoch 10/1000
#  - 0s - loss: 0.6139 - mean_squared_error: 0.6139 - mean_absolute_percentage_error: 108.5466 - val_loss: 0.6557 - val_mean_squared_error: 0.6557 - val_mean_absolute_percentage_error: 144.1796
# Epoch 11/1000
#  - 0s - loss: 0.6045 - mean_squared_error: 0.6045 - mean_absolute_percentage_error: 126.5939 - val_loss: 0.6516 - val_mean_squared_error: 0.6516 - val_mean_absolute_percentage_error: 142.2330
# Epoch 12/1000
#  - 0s - loss: 0.6005 - mean_squared_error: 0.6005 - mean_absolute_percentage_error: 115.0891 - val_loss: 0.6495 - val_mean_squared_error: 0.6495 - val_mean_absolute_percentage_error: 138.9789
# Epoch 13/1000
#  - 0s - loss: 0.5951 - mean_squared_error: 0.5951 - mean_absolute_percentage_error: 118.1136 - val_loss: 0.6527 - val_mean_squared_error: 0.6527 - val_mean_absolute_percentage_error: 137.4169
# Epoch 14/1000
#  - 0s - loss: 0.5943 - mean_squared_error: 0.5943 - mean_absolute_percentage_error: 115.0553 - val_loss: 0.6409 - val_mean_squared_error: 0.6409 - val_mean_absolute_percentage_error: 126.3739
# Epoch 15/1000
#  - 0s - loss: 0.5917 - mean_squared_error: 0.5917 - mean_absolute_percentage_error: 108.8591 - val_loss: 0.6392 - val_mean_squared_error: 0.6392 - val_mean_absolute_percentage_error: 124.1738
# Epoch 16/1000
#  - 0s - loss: 0.5905 - mean_squared_error: 0.5905 - mean_absolute_percentage_error: 108.3082 - val_loss: 0.6399 - val_mean_squared_error: 0.6399 - val_mean_absolute_percentage_error: 126.1690
# Epoch 17/1000
#  - 0s - loss: 0.5902 - mean_squared_error: 0.5902 - mean_absolute_percentage_error: 109.4031 - val_loss: 0.6385 - val_mean_squared_error: 0.6385 - val_mean_absolute_percentage_error: 124.6995
# Epoch 18/1000
#  - 0s - loss: 0.5868 - mean_squared_error: 0.5868 - mean_absolute_percentage_error: 107.1728 - val_loss: 0.6404 - val_mean_squared_error: 0.6404 - val_mean_absolute_percentage_error: 126.1415
# Epoch 19/1000
#  - 0s - loss: 0.5867 - mean_squared_error: 0.5867 - mean_absolute_percentage_error: 108.0823 - val_loss: 0.6405 - val_mean_squared_error: 0.6405 - val_mean_absolute_percentage_error: 125.3283
# Epoch 20/1000
#  - 0s - loss: 0.5850 - mean_squared_error: 0.5850 - mean_absolute_percentage_error: 107.0470 - val_loss: 0.6402 - val_mean_squared_error: 0.6402 - val_mean_absolute_percentage_error: 124.5186
# Epoch 21/1000
#  - 0s - loss: 0.5843 - mean_squared_error: 0.5843 - mean_absolute_percentage_error: 105.2972 - val_loss: 0.6420 - val_mean_squared_error: 0.6420 - val_mean_absolute_percentage_error: 125.9447
# Epoch 22/1000
#  - 0s - loss: 0.5826 - mean_squared_error: 0.5826 - mean_absolute_percentage_error: 107.1922 - val_loss: 0.6413 - val_mean_squared_error: 0.6413 - val_mean_absolute_percentage_error: 125.2407
# Epoch 23/1000
#  - 0s - loss: 0.5825 - mean_squared_error: 0.5825 - mean_absolute_percentage_error: 104.8169 - val_loss: 0.6405 - val_mean_squared_error: 0.6405 - val_mean_absolute_percentage_error: 123.6310
# Epoch 24/1000
#  - 0s - loss: 0.5817 - mean_squared_error: 0.5817 - mean_absolute_percentage_error: 106.0721 - val_loss: 0.6423 - val_mean_squared_error: 0.6423 - val_mean_absolute_percentage_error: 128.0379
# Epoch 25/1000
#  - 0s - loss: 0.5837 - mean_squared_error: 0.5837 - mean_absolute_percentage_error: 110.5904 - val_loss: 0.6404 - val_mean_squared_error: 0.6404 - val_mean_absolute_percentage_error: 124.1860
# Epoch 26/1000
#  - 0s - loss: 0.5836 - mean_squared_error: 0.5836 - mean_absolute_percentage_error: 104.6534 - val_loss: 0.6410 - val_mean_squared_error: 0.6410 - val_mean_absolute_percentage_error: 118.4217
# Epoch 27/1000
#  - 0s - loss: 0.5804 - mean_squared_error: 0.5804 - mean_absolute_percentage_error: 105.1794 - val_loss: 0.6430 - val_mean_squared_error: 0.6430 - val_mean_absolute_percentage_error: 125.8257
# Epoch 28/1000
#  - 0s - loss: 0.5812 - mean_squared_error: 0.5812 - mean_absolute_percentage_error: 108.6647 - val_loss: 0.6403 - val_mean_squared_error: 0.6403 - val_mean_absolute_percentage_error: 120.7270
# Epoch 29/1000
#  - 0s - loss: 0.5796 - mean_squared_error: 0.5796 - mean_absolute_percentage_error: 103.6052 - val_loss: 0.6403 - val_mean_squared_error: 0.6403 - val_mean_absolute_percentage_error: 118.8144
# Epoch 30/1000
#  - 0s - loss: 0.5800 - mean_squared_error: 0.5800 - mean_absolute_percentage_error: 106.9588 - val_loss: 0.6434 - val_mean_squared_error: 0.6434 - val_mean_absolute_percentage_error: 124.4308
# Epoch 31/1000
#  - 0s - loss: 0.5781 - mean_squared_error: 0.5781 - mean_absolute_percentage_error: 106.4393 - val_loss: 0.6404 - val_mean_squared_error: 0.6404 - val_mean_absolute_percentage_error: 116.3829
# Epoch 32/1000
#  - 0s - loss: 0.5783 - mean_squared_error: 0.5783 - mean_absolute_percentage_error: 102.9710 - val_loss: 0.6406 - val_mean_squared_error: 0.6406 - val_mean_absolute_percentage_error: 116.1076
# Epoch 33/1000
#  - 0s - loss: 0.5764 - mean_squared_error: 0.5764 - mean_absolute_percentage_error: 103.9986 - val_loss: 0.6414 - val_mean_squared_error: 0.6414 - val_mean_absolute_percentage_error: 120.8818
# Epoch 34/1000
#  - 0s - loss: 0.5772 - mean_squared_error: 0.5772 - mean_absolute_percentage_error: 106.3392 - val_loss: 0.6393 - val_mean_squared_error: 0.6393 - val_mean_absolute_percentage_error: 116.7995
# Epoch 35/1000
#  - 0s - loss: 0.5757 - mean_squared_error: 0.5757 - mean_absolute_percentage_error: 103.3031 - val_loss: 0.6390 - val_mean_squared_error: 0.6390 - val_mean_absolute_percentage_error: 114.2490
# Epoch 36/1000
#  - 0s - loss: 0.5758 - mean_squared_error: 0.5758 - mean_absolute_percentage_error: 103.4352 - val_loss: 0.6392 - val_mean_squared_error: 0.6392 - val_mean_absolute_percentage_error: 118.0069
# Epoch 37/1000
#  - 0s - loss: 0.5751 - mean_squared_error: 0.5751 - mean_absolute_percentage_error: 104.6816 - val_loss: 0.6379 - val_mean_squared_error: 0.6379 - val_mean_absolute_percentage_error: 114.6471
# Epoch 38/1000
#  - 0s - loss: 0.5752 - mean_squared_error: 0.5752 - mean_absolute_percentage_error: 102.2780 - val_loss: 0.6380 - val_mean_squared_error: 0.6380 - val_mean_absolute_percentage_error: 115.1515
# Epoch 39/1000
#  - 0s - loss: 0.5748 - mean_squared_error: 0.5748 - mean_absolute_percentage_error: 105.1615 - val_loss: 0.6385 - val_mean_squared_error: 0.6385 - val_mean_absolute_percentage_error: 118.1302
# Epoch 40/1000
#  - 0s - loss: 0.5740 - mean_squared_error: 0.5740 - mean_absolute_percentage_error: 104.4895 - val_loss: 0.6379 - val_mean_squared_error: 0.6379 - val_mean_absolute_percentage_error: 115.9300
# Epoch 41/1000
#  - 0s - loss: 0.5739 - mean_squared_error: 0.5739 - mean_absolute_percentage_error: 102.3203 - val_loss: 0.6375 - val_mean_squared_error: 0.6375 - val_mean_absolute_percentage_error: 115.7021
# Epoch 42/1000
#  - 0s - loss: 0.5735 - mean_squared_error: 0.5735 - mean_absolute_percentage_error: 104.1914 - val_loss: 0.6376 - val_mean_squared_error: 0.6376 - val_mean_absolute_percentage_error: 116.1459
# Epoch 43/1000
#  - 0s - loss: 0.5729 - mean_squared_error: 0.5729 - mean_absolute_percentage_error: 103.4121 - val_loss: 0.6378 - val_mean_squared_error: 0.6378 - val_mean_absolute_percentage_error: 116.6068
# Epoch 44/1000
#  - 0s - loss: 0.5726 - mean_squared_error: 0.5726 - mean_absolute_percentage_error: 103.4071 - val_loss: 0.6376 - val_mean_squared_error: 0.6376 - val_mean_absolute_percentage_error: 116.5308
# Epoch 45/1000
#  - 0s - loss: 0.5731 - mean_squared_error: 0.5731 - mean_absolute_percentage_error: 103.8859 - val_loss: 0.6374 - val_mean_squared_error: 0.6374 - val_mean_absolute_percentage_error: 116.8293
# Epoch 46/1000
#  - 0s - loss: 0.5728 - mean_squared_error: 0.5728 - mean_absolute_percentage_error: 102.8628 - val_loss: 0.6370 - val_mean_squared_error: 0.6370 - val_mean_absolute_percentage_error: 115.9500
# Epoch 47/1000
#  - 0s - loss: 0.5719 - mean_squared_error: 0.5719 - mean_absolute_percentage_error: 102.3920 - val_loss: 0.6373 - val_mean_squared_error: 0.6373 - val_mean_absolute_percentage_error: 117.8368
# Epoch 48/1000
#  - 0s - loss: 0.5717 - mean_squared_error: 0.5717 - mean_absolute_percentage_error: 103.1273 - val_loss: 0.6376 - val_mean_squared_error: 0.6376 - val_mean_absolute_percentage_error: 119.3528
# Epoch 49/1000
#  - 0s - loss: 0.5713 - mean_squared_error: 0.5713 - mean_absolute_percentage_error: 104.1619 - val_loss: 0.6368 - val_mean_squared_error: 0.6368 - val_mean_absolute_percentage_error: 116.2542
# Epoch 50/1000
#  - 0s - loss: 0.5712 - mean_squared_error: 0.5712 - mean_absolute_percentage_error: 102.2685 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 117.7327
# Epoch 51/1000
#  - 0s - loss: 0.5711 - mean_squared_error: 0.5711 - mean_absolute_percentage_error: 103.4666 - val_loss: 0.6370 - val_mean_squared_error: 0.6370 - val_mean_absolute_percentage_error: 118.7022
# Epoch 52/1000
#  - 0s - loss: 0.5707 - mean_squared_error: 0.5707 - mean_absolute_percentage_error: 103.5023 - val_loss: 0.6365 - val_mean_squared_error: 0.6365 - val_mean_absolute_percentage_error: 117.5752
# Epoch 53/1000
#  - 0s - loss: 0.5701 - mean_squared_error: 0.5701 - mean_absolute_percentage_error: 102.2852 - val_loss: 0.6371 - val_mean_squared_error: 0.6371 - val_mean_absolute_percentage_error: 119.9991
# Epoch 54/1000
#  - 0s - loss: 0.5697 - mean_squared_error: 0.5697 - mean_absolute_percentage_error: 103.5213 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 120.0001
# Epoch 55/1000
#  - 0s - loss: 0.5699 - mean_squared_error: 0.5699 - mean_absolute_percentage_error: 101.9362 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 121.1973
# Epoch 56/1000
#  - 0s - loss: 0.5693 - mean_squared_error: 0.5693 - mean_absolute_percentage_error: 102.6117 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 123.3581
# Epoch 57/1000
#  - 0s - loss: 0.5691 - mean_squared_error: 0.5691 - mean_absolute_percentage_error: 105.0509 - val_loss: 0.6362 - val_mean_squared_error: 0.6362 - val_mean_absolute_percentage_error: 123.7744
# Epoch 58/1000
#  - 0s - loss: 0.5679 - mean_squared_error: 0.5679 - mean_absolute_percentage_error: 103.4920 - val_loss: 0.6359 - val_mean_squared_error: 0.6359 - val_mean_absolute_percentage_error: 122.8027
# Epoch 59/1000
#  - 0s - loss: 0.5687 - mean_squared_error: 0.5687 - mean_absolute_percentage_error: 102.9928 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 121.5541
# Epoch 60/1000
#  - 0s - loss: 0.5682 - mean_squared_error: 0.5682 - mean_absolute_percentage_error: 101.3989 - val_loss: 0.6361 - val_mean_squared_error: 0.6361 - val_mean_absolute_percentage_error: 123.0308
# Epoch 61/1000
#  - 0s - loss: 0.5682 - mean_squared_error: 0.5682 - mean_absolute_percentage_error: 102.5265 - val_loss: 0.6362 - val_mean_squared_error: 0.6362 - val_mean_absolute_percentage_error: 122.7898
# Epoch 62/1000
#  - 0s - loss: 0.5669 - mean_squared_error: 0.5669 - mean_absolute_percentage_error: 102.5672 - val_loss: 0.6366 - val_mean_squared_error: 0.6366 - val_mean_absolute_percentage_error: 122.7275
# Epoch 63/1000
#  - 0s - loss: 0.5676 - mean_squared_error: 0.5676 - mean_absolute_percentage_error: 103.3298 - val_loss: 0.6366 - val_mean_squared_error: 0.6366 - val_mean_absolute_percentage_error: 122.0910
# Epoch 64/1000
#  - 0s - loss: 0.5668 - mean_squared_error: 0.5668 - mean_absolute_percentage_error: 102.5819 - val_loss: 0.6375 - val_mean_squared_error: 0.6375 - val_mean_absolute_percentage_error: 123.9888
# Epoch 65/1000
#  - 0s - loss: 0.5668 - mean_squared_error: 0.5668 - mean_absolute_percentage_error: 100.9070 - val_loss: 0.6364 - val_mean_squared_error: 0.6364 - val_mean_absolute_percentage_error: 121.2310
# Epoch 66/1000
#  - 0s - loss: 0.5667 - mean_squared_error: 0.5667 - mean_absolute_percentage_error: 101.0824 - val_loss: 0.6374 - val_mean_squared_error: 0.6374 - val_mean_absolute_percentage_error: 124.2689
# Epoch 67/1000
#  - 0s - loss: 0.5664 - mean_squared_error: 0.5664 - mean_absolute_percentage_error: 101.8695 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 123.2991
# Epoch 68/1000
#  - 0s - loss: 0.5666 - mean_squared_error: 0.5666 - mean_absolute_percentage_error: 100.1943 - val_loss: 0.6367 - val_mean_squared_error: 0.6367 - val_mean_absolute_percentage_error: 123.1254
# Epoch 69/1000
#  - 0s - loss: 0.5663 - mean_squared_error: 0.5663 - mean_absolute_percentage_error: 101.5442 - val_loss: 0.6375 - val_mean_squared_error: 0.6375 - val_mean_absolute_percentage_error: 124.1278
# Epoch 70/1000
#  - 0s - loss: 0.5660 - mean_squared_error: 0.5660 - mean_absolute_percentage_error: 99.8990 - val_loss: 0.6364 - val_mean_squared_error: 0.6364 - val_mean_absolute_percentage_error: 123.0234
# Epoch 71/1000
#  - 0s - loss: 0.5658 - mean_squared_error: 0.5658 - mean_absolute_percentage_error: 98.6251 - val_loss: 0.6378 - val_mean_squared_error: 0.6378 - val_mean_absolute_percentage_error: 124.9588
# Epoch 72/1000
#  - 0s - loss: 0.5658 - mean_squared_error: 0.5658 - mean_absolute_percentage_error: 99.5653 - val_loss: 0.6361 - val_mean_squared_error: 0.6361 - val_mean_absolute_percentage_error: 122.0603
# Epoch 73/1000
#  - 0s - loss: 0.5659 - mean_squared_error: 0.5659 - mean_absolute_percentage_error: 98.8318 - val_loss: 0.6360 - val_mean_squared_error: 0.6360 - val_mean_absolute_percentage_error: 124.0102
# Epoch 74/1000
#  - 0s - loss: 0.5656 - mean_squared_error: 0.5656 - mean_absolute_percentage_error: 101.1224 - val_loss: 0.6372 - val_mean_squared_error: 0.6372 - val_mean_absolute_percentage_error: 125.2766
# Epoch 75/1000
#  - 0s - loss: 0.5658 - mean_squared_error: 0.5658 - mean_absolute_percentage_error: 99.9067 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 120.7070
# Epoch 76/1000
#  - 0s - loss: 0.5655 - mean_squared_error: 0.5655 - mean_absolute_percentage_error: 98.5947 - val_loss: 0.6374 - val_mean_squared_error: 0.6374 - val_mean_absolute_percentage_error: 126.4212
# Epoch 77/1000
#  - 0s - loss: 0.5652 - mean_squared_error: 0.5652 - mean_absolute_percentage_error: 100.4761 - val_loss: 0.6355 - val_mean_squared_error: 0.6355 - val_mean_absolute_percentage_error: 121.8171
# Epoch 78/1000
#  - 0s - loss: 0.5650 - mean_squared_error: 0.5650 - mean_absolute_percentage_error: 97.7873 - val_loss: 0.6376 - val_mean_squared_error: 0.6376 - val_mean_absolute_percentage_error: 125.3399
# Epoch 79/1000
#  - 0s - loss: 0.5657 - mean_squared_error: 0.5657 - mean_absolute_percentage_error: 101.9031 - val_loss: 0.6361 - val_mean_squared_error: 0.6361 - val_mean_absolute_percentage_error: 123.6404
# Epoch 80/1000
#  - 0s - loss: 0.5649 - mean_squared_error: 0.5649 - mean_absolute_percentage_error: 96.9235 - val_loss: 0.6360 - val_mean_squared_error: 0.6360 - val_mean_absolute_percentage_error: 123.3496
# Epoch 81/1000
#  - 0s - loss: 0.5643 - mean_squared_error: 0.5643 - mean_absolute_percentage_error: 99.4277 - val_loss: 0.6380 - val_mean_squared_error: 0.6380 - val_mean_absolute_percentage_error: 126.9201
# Epoch 82/1000
#  - 0s - loss: 0.5649 - mean_squared_error: 0.5649 - mean_absolute_percentage_error: 99.1198 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 122.3208
# Epoch 83/1000
#  - 0s - loss: 0.5645 - mean_squared_error: 0.5645 - mean_absolute_percentage_error: 97.7025 - val_loss: 0.6370 - val_mean_squared_error: 0.6370 - val_mean_absolute_percentage_error: 124.8130
# Epoch 84/1000
#  - 0s - loss: 0.5645 - mean_squared_error: 0.5645 - mean_absolute_percentage_error: 99.4393 - val_loss: 0.6360 - val_mean_squared_error: 0.6360 - val_mean_absolute_percentage_error: 124.2075
# Epoch 85/1000
#  - 0s - loss: 0.5643 - mean_squared_error: 0.5643 - mean_absolute_percentage_error: 99.1928 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 124.3525
# Epoch 86/1000
#  - 0s - loss: 0.5645 - mean_squared_error: 0.5645 - mean_absolute_percentage_error: 99.0564 - val_loss: 0.6360 - val_mean_squared_error: 0.6360 - val_mean_absolute_percentage_error: 123.3016
# Epoch 87/1000
#  - 0s - loss: 0.5637 - mean_squared_error: 0.5637 - mean_absolute_percentage_error: 94.9193 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 124.0218
# Epoch 88/1000
#  - 0s - loss: 0.5641 - mean_squared_error: 0.5641 - mean_absolute_percentage_error: 97.3969 - val_loss: 0.6367 - val_mean_squared_error: 0.6367 - val_mean_absolute_percentage_error: 125.1851
# Epoch 89/1000
#  - 0s - loss: 0.5639 - mean_squared_error: 0.5639 - mean_absolute_percentage_error: 96.7968 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 123.0146
# Epoch 90/1000
#  - 0s - loss: 0.5638 - mean_squared_error: 0.5638 - mean_absolute_percentage_error: 95.6939 - val_loss: 0.6371 - val_mean_squared_error: 0.6371 - val_mean_absolute_percentage_error: 126.2312
# Epoch 91/1000
#  - 0s - loss: 0.5642 - mean_squared_error: 0.5642 - mean_absolute_percentage_error: 99.5730 - val_loss: 0.6366 - val_mean_squared_error: 0.6366 - val_mean_absolute_percentage_error: 124.0722
# Epoch 92/1000
#  - 0s - loss: 0.5648 - mean_squared_error: 0.5648 - mean_absolute_percentage_error: 94.4681 - val_loss: 0.6364 - val_mean_squared_error: 0.6364 - val_mean_absolute_percentage_error: 124.5964
# Epoch 93/1000
#  - 0s - loss: 0.5652 - mean_squared_error: 0.5652 - mean_absolute_percentage_error: 99.6010 - val_loss: 0.6403 - val_mean_squared_error: 0.6403 - val_mean_absolute_percentage_error: 128.3745
# Epoch 94/1000
#  - 0s - loss: 0.5639 - mean_squared_error: 0.5639 - mean_absolute_percentage_error: 94.3261 - val_loss: 0.6359 - val_mean_squared_error: 0.6359 - val_mean_absolute_percentage_error: 120.7872
# Epoch 95/1000
#  - 0s - loss: 0.5641 - mean_squared_error: 0.5641 - mean_absolute_percentage_error: 94.9619 - val_loss: 0.6399 - val_mean_squared_error: 0.6399 - val_mean_absolute_percentage_error: 128.9231
# Epoch 96/1000
#  - 0s - loss: 0.5635 - mean_squared_error: 0.5635 - mean_absolute_percentage_error: 97.4056 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 122.1007
# Epoch 97/1000
#  - 0s - loss: 0.5634 - mean_squared_error: 0.5634 - mean_absolute_percentage_error: 93.0074 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 122.8965
# Epoch 98/1000
#  - 0s - loss: 0.5632 - mean_squared_error: 0.5632 - mean_absolute_percentage_error: 95.6467 - val_loss: 0.6363 - val_mean_squared_error: 0.6363 - val_mean_absolute_percentage_error: 125.1734
# Epoch 99/1000
#  - 0s - loss: 0.5626 - mean_squared_error: 0.5626 - mean_absolute_percentage_error: 94.1397 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 122.9393
# Epoch 100/1000
#  - 0s - loss: 0.5624 - mean_squared_error: 0.5624 - mean_absolute_percentage_error: 92.8599 - val_loss: 0.6369 - val_mean_squared_error: 0.6369 - val_mean_absolute_percentage_error: 125.4441
# Epoch 101/1000
#  - 0s - loss: 0.5626 - mean_squared_error: 0.5626 - mean_absolute_percentage_error: 95.6798 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 123.2089
# Epoch 102/1000
#  - 0s - loss: 0.5627 - mean_squared_error: 0.5627 - mean_absolute_percentage_error: 93.4585 - val_loss: 0.6365 - val_mean_squared_error: 0.6365 - val_mean_absolute_percentage_error: 125.2084
# Epoch 103/1000
#  - 0s - loss: 0.5630 - mean_squared_error: 0.5630 - mean_absolute_percentage_error: 95.8068 - val_loss: 0.6366 - val_mean_squared_error: 0.6366 - val_mean_absolute_percentage_error: 124.7260
# Epoch 104/1000
#  - 0s - loss: 0.5623 - mean_squared_error: 0.5623 - mean_absolute_percentage_error: 91.8960 - val_loss: 0.6358 - val_mean_squared_error: 0.6358 - val_mean_absolute_percentage_error: 123.8018
# Epoch 105/1000
#  - 0s - loss: 0.5625 - mean_squared_error: 0.5625 - mean_absolute_percentage_error: 93.4550 - val_loss: 0.6377 - val_mean_squared_error: 0.6377 - val_mean_absolute_percentage_error: 127.4953
# Epoch 106/1000
#  - 0s - loss: 0.5624 - mean_squared_error: 0.5624 - mean_absolute_percentage_error: 94.9767 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 123.0580
# Epoch 107/1000
#  - 0s - loss: 0.5622 - mean_squared_error: 0.5622 - mean_absolute_percentage_error: 92.4432 - val_loss: 0.6352 - val_mean_squared_error: 0.6352 - val_mean_absolute_percentage_error: 124.3277
# Epoch 108/1000
#  - 0s - loss: 0.5622 - mean_squared_error: 0.5622 - mean_absolute_percentage_error: 93.6752 - val_loss: 0.6360 - val_mean_squared_error: 0.6360 - val_mean_absolute_percentage_error: 126.4010
# Epoch 109/1000
#  - 0s - loss: 0.5619 - mean_squared_error: 0.5619 - mean_absolute_percentage_error: 91.7473 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 123.2958
# Epoch 110/1000
#  - 0s - loss: 0.5619 - mean_squared_error: 0.5619 - mean_absolute_percentage_error: 93.0955 - val_loss: 0.6359 - val_mean_squared_error: 0.6359 - val_mean_absolute_percentage_error: 126.2434
# Epoch 111/1000
#  - 0s - loss: 0.5615 - mean_squared_error: 0.5615 - mean_absolute_percentage_error: 92.8745 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 124.1486
# Epoch 112/1000
#  - 0s - loss: 0.5617 - mean_squared_error: 0.5617 - mean_absolute_percentage_error: 92.5395 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 124.4522
# Epoch 113/1000
#  - 0s - loss: 0.5615 - mean_squared_error: 0.5615 - mean_absolute_percentage_error: 93.6789 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 125.9280
# Epoch 114/1000
#  - 0s - loss: 0.5613 - mean_squared_error: 0.5613 - mean_absolute_percentage_error: 92.6044 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 124.8512
# Epoch 115/1000
#  - 0s - loss: 0.5615 - mean_squared_error: 0.5615 - mean_absolute_percentage_error: 93.2310 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 125.4268
# Epoch 116/1000
#  - 0s - loss: 0.5615 - mean_squared_error: 0.5615 - mean_absolute_percentage_error: 92.2748 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 124.4242
# Epoch 117/1000
#  - 0s - loss: 0.5618 - mean_squared_error: 0.5618 - mean_absolute_percentage_error: 93.1421 - val_loss: 0.6338 - val_mean_squared_error: 0.6338 - val_mean_absolute_percentage_error: 124.4646
# Epoch 118/1000
#  - 0s - loss: 0.5612 - mean_squared_error: 0.5612 - mean_absolute_percentage_error: 93.0713 - val_loss: 0.6338 - val_mean_squared_error: 0.6338 - val_mean_absolute_percentage_error: 125.8105
# Epoch 119/1000
#  - 0s - loss: 0.5611 - mean_squared_error: 0.5611 - mean_absolute_percentage_error: 92.8941 - val_loss: 0.6337 - val_mean_squared_error: 0.6337 - val_mean_absolute_percentage_error: 124.6701
# Epoch 120/1000
#  - 0s - loss: 0.5611 - mean_squared_error: 0.5611 - mean_absolute_percentage_error: 92.5233 - val_loss: 0.6341 - val_mean_squared_error: 0.6341 - val_mean_absolute_percentage_error: 124.4442
# Epoch 121/1000
#  - 0s - loss: 0.5609 - mean_squared_error: 0.5609 - mean_absolute_percentage_error: 91.6812 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 125.6101
# Epoch 122/1000
#  - 0s - loss: 0.5609 - mean_squared_error: 0.5609 - mean_absolute_percentage_error: 92.7710 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 126.6804
# Epoch 123/1000
#  - 0s - loss: 0.5611 - mean_squared_error: 0.5611 - mean_absolute_percentage_error: 91.8939 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 124.8007
# Epoch 124/1000
#  - 0s - loss: 0.5607 - mean_squared_error: 0.5607 - mean_absolute_percentage_error: 90.6478 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 125.7693
# Epoch 125/1000
#  - 0s - loss: 0.5609 - mean_squared_error: 0.5609 - mean_absolute_percentage_error: 92.3644 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 124.6440
# Epoch 126/1000
#  - 0s - loss: 0.5607 - mean_squared_error: 0.5607 - mean_absolute_percentage_error: 92.1622 - val_loss: 0.6337 - val_mean_squared_error: 0.6337 - val_mean_absolute_percentage_error: 123.5449
# Epoch 127/1000
#  - 0s - loss: 0.5607 - mean_squared_error: 0.5607 - mean_absolute_percentage_error: 92.8219 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 123.6488
# Epoch 128/1000
#  - 0s - loss: 0.5608 - mean_squared_error: 0.5608 - mean_absolute_percentage_error: 92.3979 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 124.2966
# Epoch 129/1000
#  - 0s - loss: 0.5607 - mean_squared_error: 0.5607 - mean_absolute_percentage_error: 92.3167 - val_loss: 0.6341 - val_mean_squared_error: 0.6341 - val_mean_absolute_percentage_error: 124.8437
# Epoch 130/1000
#  - 0s - loss: 0.5605 - mean_squared_error: 0.5605 - mean_absolute_percentage_error: 92.6263 - val_loss: 0.6343 - val_mean_squared_error: 0.6343 - val_mean_absolute_percentage_error: 125.0626
# Epoch 131/1000
#  - 0s - loss: 0.5606 - mean_squared_error: 0.5606 - mean_absolute_percentage_error: 92.0995 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 124.0615
# Epoch 132/1000
#  - 0s - loss: 0.5604 - mean_squared_error: 0.5604 - mean_absolute_percentage_error: 91.0125 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 125.5743
# Epoch 133/1000
#  - 0s - loss: 0.5608 - mean_squared_error: 0.5608 - mean_absolute_percentage_error: 91.6203 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 124.6322
# Epoch 134/1000
#  - 0s - loss: 0.5602 - mean_squared_error: 0.5602 - mean_absolute_percentage_error: 92.5434 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 124.4838
# Epoch 135/1000
#  - 0s - loss: 0.5603 - mean_squared_error: 0.5603 - mean_absolute_percentage_error: 91.3305 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_percentage_error: 124.0524
# Epoch 136/1000
#  - 0s - loss: 0.5602 - mean_squared_error: 0.5602 - mean_absolute_percentage_error: 92.1567 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 125.7323
# Epoch 137/1000
#  - 0s - loss: 0.5603 - mean_squared_error: 0.5603 - mean_absolute_percentage_error: 92.5575 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_percentage_error: 124.1400
# Epoch 138/1000
#  - 0s - loss: 0.5603 - mean_squared_error: 0.5603 - mean_absolute_percentage_error: 92.3284 - val_loss: 0.6343 - val_mean_squared_error: 0.6343 - val_mean_absolute_percentage_error: 126.0753
# Epoch 139/1000
#  - 0s - loss: 0.5603 - mean_squared_error: 0.5603 - mean_absolute_percentage_error: 92.0315 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_percentage_error: 124.5715
# Epoch 140/1000
#  - 0s - loss: 0.5601 - mean_squared_error: 0.5601 - mean_absolute_percentage_error: 91.8173 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 125.0746
# Epoch 141/1000
#  - 0s - loss: 0.5601 - mean_squared_error: 0.5601 - mean_absolute_percentage_error: 92.1508 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 125.0599
# Epoch 142/1000
#  - 0s - loss: 0.5600 - mean_squared_error: 0.5600 - mean_absolute_percentage_error: 91.0055 - val_loss: 0.6335 - val_mean_squared_error: 0.6335 - val_mean_absolute_percentage_error: 124.8132
# Epoch 143/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 91.8712 - val_loss: 0.6333 - val_mean_squared_error: 0.6333 - val_mean_absolute_percentage_error: 124.2861
# Epoch 144/1000
#  - 0s - loss: 0.5598 - mean_squared_error: 0.5598 - mean_absolute_percentage_error: 91.6619 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 126.0207
# Epoch 145/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 91.5081 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 124.7428
# Epoch 146/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 90.6348 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 125.5723
# Epoch 147/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 92.3902 - val_loss: 0.6338 - val_mean_squared_error: 0.6338 - val_mean_absolute_percentage_error: 124.8755
# Epoch 148/1000
#  - 0s - loss: 0.5596 - mean_squared_error: 0.5596 - mean_absolute_percentage_error: 91.1116 - val_loss: 0.6338 - val_mean_squared_error: 0.6338 - val_mean_absolute_percentage_error: 123.9425
# Epoch 149/1000
#  - 0s - loss: 0.5596 - mean_squared_error: 0.5596 - mean_absolute_percentage_error: 90.7516 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 127.6151
# Epoch 150/1000
#  - 0s - loss: 0.5598 - mean_squared_error: 0.5598 - mean_absolute_percentage_error: 92.7383 - val_loss: 0.6341 - val_mean_squared_error: 0.6341 - val_mean_absolute_percentage_error: 125.4354
# Epoch 151/1000
#  - 0s - loss: 0.5597 - mean_squared_error: 0.5597 - mean_absolute_percentage_error: 91.0476 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 125.5244
# Epoch 152/1000
#  - 0s - loss: 0.5598 - mean_squared_error: 0.5598 - mean_absolute_percentage_error: 91.8686 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 127.2653
# Epoch 153/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 91.4364 - val_loss: 0.6343 - val_mean_squared_error: 0.6343 - val_mean_absolute_percentage_error: 126.7499
# Epoch 154/1000
#  - 0s - loss: 0.5597 - mean_squared_error: 0.5597 - mean_absolute_percentage_error: 91.9727 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 126.6127
# Epoch 155/1000
#  - 0s - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_percentage_error: 91.7263 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 125.3058
# Epoch 156/1000
#  - 0s - loss: 0.5599 - mean_squared_error: 0.5599 - mean_absolute_percentage_error: 90.9611 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 126.8425
# Epoch 157/1000
#  - 0s - loss: 0.5598 - mean_squared_error: 0.5598 - mean_absolute_percentage_error: 92.3932 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 125.8763
# Epoch 158/1000
#  - 0s - loss: 0.5597 - mean_squared_error: 0.5597 - mean_absolute_percentage_error: 90.1355 - val_loss: 0.6333 - val_mean_squared_error: 0.6333 - val_mean_absolute_percentage_error: 123.3544
# Epoch 159/1000
#  - 0s - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_percentage_error: 89.7467 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 125.4624
# Epoch 160/1000
#  - 0s - loss: 0.5596 - mean_squared_error: 0.5596 - mean_absolute_percentage_error: 91.3338 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 125.8226
# Epoch 161/1000
#  - 0s - loss: 0.5597 - mean_squared_error: 0.5597 - mean_absolute_percentage_error: 91.0433 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 126.3659
# Epoch 162/1000
#  - 0s - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_percentage_error: 91.7428 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 126.0503
# Epoch 163/1000
#  - 0s - loss: 0.5594 - mean_squared_error: 0.5594 - mean_absolute_percentage_error: 92.0904 - val_loss: 0.6338 - val_mean_squared_error: 0.6338 - val_mean_absolute_percentage_error: 124.7545
# Epoch 164/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 91.7802 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 126.0640
# Epoch 165/1000
#  - 0s - loss: 0.5592 - mean_squared_error: 0.5592 - mean_absolute_percentage_error: 89.4613 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 126.2733
# Epoch 166/1000
#  - 0s - loss: 0.5594 - mean_squared_error: 0.5594 - mean_absolute_percentage_error: 91.1725 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 127.4046
# Epoch 167/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 89.8658 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 127.7694
# Epoch 168/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 90.1359 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 125.8814
# Epoch 169/1000
#  - 0s - loss: 0.5593 - mean_squared_error: 0.5593 - mean_absolute_percentage_error: 90.1437 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 126.3527
# Epoch 170/1000
#  - 0s - loss: 0.5593 - mean_squared_error: 0.5593 - mean_absolute_percentage_error: 90.7255 - val_loss: 0.6341 - val_mean_squared_error: 0.6341 - val_mean_absolute_percentage_error: 127.0953
# Epoch 171/1000
#  - 0s - loss: 0.5594 - mean_squared_error: 0.5594 - mean_absolute_percentage_error: 90.6785 - val_loss: 0.6332 - val_mean_squared_error: 0.6332 - val_mean_absolute_percentage_error: 124.2474
# Epoch 172/1000
#  - 0s - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_percentage_error: 90.2621 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 126.5193
# Epoch 173/1000
#  - 0s - loss: 0.5595 - mean_squared_error: 0.5595 - mean_absolute_percentage_error: 91.4749 - val_loss: 0.6337 - val_mean_squared_error: 0.6337 - val_mean_absolute_percentage_error: 125.1335
# Epoch 174/1000
#  - 0s - loss: 0.5592 - mean_squared_error: 0.5592 - mean_absolute_percentage_error: 92.2615 - val_loss: 0.6334 - val_mean_squared_error: 0.6334 - val_mean_absolute_percentage_error: 123.9033
# Epoch 175/1000
#  - 0s - loss: 0.5593 - mean_squared_error: 0.5593 - mean_absolute_percentage_error: 89.3061 - val_loss: 0.6337 - val_mean_squared_error: 0.6337 - val_mean_absolute_percentage_error: 124.5461
# Epoch 176/1000
#  - 0s - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_percentage_error: 89.8646 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 125.9956
# Epoch 177/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 90.6507 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 126.6406
# Epoch 178/1000
#  - 0s - loss: 0.5590 - mean_squared_error: 0.5590 - mean_absolute_percentage_error: 90.0573 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 124.7811
# Epoch 179/1000
#  - 0s - loss: 0.5590 - mean_squared_error: 0.5590 - mean_absolute_percentage_error: 89.1029 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 126.8002
# Epoch 180/1000
#  - 0s - loss: 0.5592 - mean_squared_error: 0.5592 - mean_absolute_percentage_error: 91.6126 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 126.2291
# Epoch 181/1000
#  - 0s - loss: 0.5593 - mean_squared_error: 0.5593 - mean_absolute_percentage_error: 90.2817 - val_loss: 0.6341 - val_mean_squared_error: 0.6341 - val_mean_absolute_percentage_error: 125.3360
# Epoch 182/1000
#  - 0s - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_percentage_error: 90.5163 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.8132
# Epoch 183/1000
#  - 0s - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_percentage_error: 89.8248 - val_loss: 0.6345 - val_mean_squared_error: 0.6345 - val_mean_absolute_percentage_error: 125.8751
# Epoch 184/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 89.5885 - val_loss: 0.6343 - val_mean_squared_error: 0.6343 - val_mean_absolute_percentage_error: 124.9340
# Epoch 185/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 90.0904 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 126.9787
# Epoch 186/1000
#  - 0s - loss: 0.5587 - mean_squared_error: 0.5587 - mean_absolute_percentage_error: 89.6981 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 124.9698
# Epoch 187/1000
#  - 0s - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_percentage_error: 89.1633 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 128.1038
# Epoch 188/1000
#  - 0s - loss: 0.5587 - mean_squared_error: 0.5587 - mean_absolute_percentage_error: 90.6165 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 126.7211
# Epoch 189/1000
#  - 0s - loss: 0.5586 - mean_squared_error: 0.5586 - mean_absolute_percentage_error: 90.0106 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 125.5236
# Epoch 190/1000
#  - 0s - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_percentage_error: 89.3464 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 128.0883
# Epoch 191/1000
#  - 0s - loss: 0.5586 - mean_squared_error: 0.5586 - mean_absolute_percentage_error: 90.3783 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 125.7007
# Epoch 192/1000
#  - 0s - loss: 0.5590 - mean_squared_error: 0.5590 - mean_absolute_percentage_error: 89.3886 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 124.6350
# Epoch 193/1000
#  - 0s - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_percentage_error: 89.7870 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 126.0263
# Epoch 194/1000
#  - 0s - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_percentage_error: 88.6521 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 125.2366
# Epoch 195/1000
#  - 0s - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_percentage_error: 89.4673 - val_loss: 0.6357 - val_mean_squared_error: 0.6357 - val_mean_absolute_percentage_error: 127.8047
# Epoch 196/1000
#  - 0s - loss: 0.5590 - mean_squared_error: 0.5590 - mean_absolute_percentage_error: 89.7207 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 125.9373
# Epoch 197/1000
#  - 0s - loss: 0.5589 - mean_squared_error: 0.5589 - mean_absolute_percentage_error: 90.5246 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 126.6842
# Epoch 198/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 92.4761 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 128.1183
# Epoch 199/1000
#  - 0s - loss: 0.5588 - mean_squared_error: 0.5588 - mean_absolute_percentage_error: 88.7446 - val_loss: 0.6339 - val_mean_squared_error: 0.6339 - val_mean_absolute_percentage_error: 123.3502
# Epoch 200/1000
#  - 0s - loss: 0.5590 - mean_squared_error: 0.5590 - mean_absolute_percentage_error: 90.3067 - val_loss: 0.6355 - val_mean_squared_error: 0.6355 - val_mean_absolute_percentage_error: 129.0441
# Epoch 201/1000
#  - 0s - loss: 0.5591 - mean_squared_error: 0.5591 - mean_absolute_percentage_error: 90.6403 - val_loss: 0.6335 - val_mean_squared_error: 0.6335 - val_mean_absolute_percentage_error: 123.5203
# Epoch 202/1000
#  - 0s - loss: 0.5586 - mean_squared_error: 0.5586 - mean_absolute_percentage_error: 87.1702 - val_loss: 0.6334 - val_mean_squared_error: 0.6334 - val_mean_absolute_percentage_error: 123.4808
# Epoch 203/1000
#  - 0s - loss: 0.5587 - mean_squared_error: 0.5587 - mean_absolute_percentage_error: 89.2030 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 128.4143
# Epoch 204/1000
#  - 0s - loss: 0.5586 - mean_squared_error: 0.5586 - mean_absolute_percentage_error: 89.6969 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 125.7456
# Epoch 205/1000
#  - 0s - loss: 0.5587 - mean_squared_error: 0.5587 - mean_absolute_percentage_error: 88.6919 - val_loss: 0.6356 - val_mean_squared_error: 0.6356 - val_mean_absolute_percentage_error: 129.7093
# Epoch 206/1000
#  - 0s - loss: 0.5585 - mean_squared_error: 0.5585 - mean_absolute_percentage_error: 90.8379 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 127.0546
# Epoch 207/1000
#  - 0s - loss: 0.5586 - mean_squared_error: 0.5586 - mean_absolute_percentage_error: 89.2882 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 126.7534
# Epoch 208/1000
#  - 0s - loss: 0.5584 - mean_squared_error: 0.5584 - mean_absolute_percentage_error: 90.2597 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 127.7993
# Epoch 209/1000
#  - 0s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_percentage_error: 89.1275 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.6451
# Epoch 210/1000
#  - 0s - loss: 0.5585 - mean_squared_error: 0.5585 - mean_absolute_percentage_error: 90.2179 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 126.7728
# Epoch 211/1000
#  - 0s - loss: 0.5583 - mean_squared_error: 0.5583 - mean_absolute_percentage_error: 89.4993 - val_loss: 0.6352 - val_mean_squared_error: 0.6352 - val_mean_absolute_percentage_error: 127.5755
# Epoch 212/1000
#  - 0s - loss: 0.5580 - mean_squared_error: 0.5580 - mean_absolute_percentage_error: 88.8547 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.5911
# Epoch 213/1000
#  - 0s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_percentage_error: 88.8302 - val_loss: 0.6349 - val_mean_squared_error: 0.6349 - val_mean_absolute_percentage_error: 127.3304
# Epoch 214/1000
#  - 0s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_percentage_error: 91.0296 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 127.1104
# Epoch 215/1000
#  - 0s - loss: 0.5585 - mean_squared_error: 0.5585 - mean_absolute_percentage_error: 89.6686 - val_loss: 0.6352 - val_mean_squared_error: 0.6352 - val_mean_absolute_percentage_error: 129.0195
# Epoch 216/1000
#  - 0s - loss: 0.5584 - mean_squared_error: 0.5584 - mean_absolute_percentage_error: 89.6988 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.5281
# Epoch 217/1000
#  - 0s - loss: 0.5585 - mean_squared_error: 0.5585 - mean_absolute_percentage_error: 89.3255 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 125.6876
# Epoch 218/1000
#  - 0s - loss: 0.5584 - mean_squared_error: 0.5584 - mean_absolute_percentage_error: 88.5420 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 126.7303
# Epoch 219/1000
#  - 0s - loss: 0.5584 - mean_squared_error: 0.5584 - mean_absolute_percentage_error: 89.5604 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.5826
# Epoch 220/1000
#  - 0s - loss: 0.5583 - mean_squared_error: 0.5583 - mean_absolute_percentage_error: 88.9573 - val_loss: 0.6344 - val_mean_squared_error: 0.6344 - val_mean_absolute_percentage_error: 124.9748
# Epoch 221/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 88.4614 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 127.4682
# Epoch 222/1000
#  - 0s - loss: 0.5583 - mean_squared_error: 0.5583 - mean_absolute_percentage_error: 88.6662 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 126.0081
# Epoch 223/1000
#  - 0s - loss: 0.5580 - mean_squared_error: 0.5580 - mean_absolute_percentage_error: 87.9341 - val_loss: 0.6348 - val_mean_squared_error: 0.6348 - val_mean_absolute_percentage_error: 125.0738
# Epoch 224/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 87.9241 - val_loss: 0.6350 - val_mean_squared_error: 0.6350 - val_mean_absolute_percentage_error: 126.8922
# Epoch 225/1000
#  - 0s - loss: 0.5580 - mean_squared_error: 0.5580 - mean_absolute_percentage_error: 87.7909 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 126.4091
# Epoch 226/1000
#  - 0s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_percentage_error: 87.7087 - val_loss: 0.6346 - val_mean_squared_error: 0.6346 - val_mean_absolute_percentage_error: 126.0434
# Epoch 227/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 88.5958 - val_loss: 0.6353 - val_mean_squared_error: 0.6353 - val_mean_absolute_percentage_error: 128.2790
# Epoch 228/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 89.1261 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 124.7294
# Epoch 229/1000
#  - 0s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_percentage_error: 87.6880 - val_loss: 0.6351 - val_mean_squared_error: 0.6351 - val_mean_absolute_percentage_error: 126.4060
# Epoch 230/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 89.3134 - val_loss: 0.6355 - val_mean_squared_error: 0.6355 - val_mean_absolute_percentage_error: 127.5340
# Epoch 231/1000
#  - 0s - loss: 0.5581 - mean_squared_error: 0.5581 - mean_absolute_percentage_error: 87.9879 - val_loss: 0.6347 - val_mean_squared_error: 0.6347 - val_mean_absolute_percentage_error: 125.2192
# Epoch 232/1000
#  - 0s - loss: 0.5580 - mean_squared_error: 0.5580 - mean_absolute_percentage_error: 86.7787 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 123.9644
# Epoch 233/1000
# ...
# Epoch 924/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.5416 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_percentage_error: 129.6047
# Epoch 925/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.4091 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 128.9146
# Epoch 926/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 78.9811 - val_loss: 0.6308 - val_mean_squared_error: 0.6308 - val_mean_absolute_percentage_error: 128.7384
# Epoch 927/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.0691 - val_loss: 0.6314 - val_mean_squared_error: 0.6314 - val_mean_absolute_percentage_error: 128.4748
# Epoch 928/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 80.1924 - val_loss: 0.6331 - val_mean_squared_error: 0.6331 - val_mean_absolute_percentage_error: 128.2246
# Epoch 929/1000
#  - 0s - loss: 0.5557 - mean_squared_error: 0.5557 - mean_absolute_percentage_error: 82.4165 - val_loss: 0.6327 - val_mean_squared_error: 0.6327 - val_mean_absolute_percentage_error: 130.0374
# Epoch 930/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 81.5169 - val_loss: 0.6316 - val_mean_squared_error: 0.6316 - val_mean_absolute_percentage_error: 128.7024
# Epoch 931/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 81.8408 - val_loss: 0.6335 - val_mean_squared_error: 0.6335 - val_mean_absolute_percentage_error: 128.3823
# Epoch 932/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.1785 - val_loss: 0.6328 - val_mean_squared_error: 0.6328 - val_mean_absolute_percentage_error: 128.9708
# Epoch 933/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.4717 - val_loss: 0.6329 - val_mean_squared_error: 0.6329 - val_mean_absolute_percentage_error: 129.3448
# Epoch 934/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.3055 - val_loss: 0.6340 - val_mean_squared_error: 0.6340 - val_mean_absolute_percentage_error: 129.5152
# Epoch 935/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 80.1429 - val_loss: 0.6333 - val_mean_squared_error: 0.6333 - val_mean_absolute_percentage_error: 128.2510
# Epoch 936/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.5548 - val_loss: 0.6318 - val_mean_squared_error: 0.6318 - val_mean_absolute_percentage_error: 129.5051
# Epoch 937/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.5452 - val_loss: 0.6315 - val_mean_squared_error: 0.6315 - val_mean_absolute_percentage_error: 128.4781
# Epoch 938/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.0079 - val_loss: 0.6326 - val_mean_squared_error: 0.6326 - val_mean_absolute_percentage_error: 127.7812
# Epoch 939/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 79.4114 - val_loss: 0.6329 - val_mean_squared_error: 0.6329 - val_mean_absolute_percentage_error: 129.0689
# Epoch 940/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 78.3854 - val_loss: 0.6316 - val_mean_squared_error: 0.6316 - val_mean_absolute_percentage_error: 127.8364
# Epoch 941/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.4584 - val_loss: 0.6316 - val_mean_squared_error: 0.6316 - val_mean_absolute_percentage_error: 127.7910
# Epoch 942/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.2139 - val_loss: 0.6328 - val_mean_squared_error: 0.6328 - val_mean_absolute_percentage_error: 129.4624
# Epoch 943/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.0415 - val_loss: 0.6320 - val_mean_squared_error: 0.6320 - val_mean_absolute_percentage_error: 126.8066
# Epoch 944/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.6209 - val_loss: 0.6306 - val_mean_squared_error: 0.6306 - val_mean_absolute_percentage_error: 128.0316
# Epoch 945/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.4431 - val_loss: 0.6310 - val_mean_squared_error: 0.6310 - val_mean_absolute_percentage_error: 129.1485
# Epoch 946/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.1481 - val_loss: 0.6322 - val_mean_squared_error: 0.6322 - val_mean_absolute_percentage_error: 128.5824
# Epoch 947/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.9084 - val_loss: 0.6308 - val_mean_squared_error: 0.6308 - val_mean_absolute_percentage_error: 127.8668
# Epoch 948/1000
#  - 0s - loss: 0.5553 - mean_squared_error: 0.5553 - mean_absolute_percentage_error: 79.3207 - val_loss: 0.6303 - val_mean_squared_error: 0.6303 - val_mean_absolute_percentage_error: 128.8496
# Epoch 949/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.6678 - val_loss: 0.6308 - val_mean_squared_error: 0.6308 - val_mean_absolute_percentage_error: 128.8893
# Epoch 950/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.6230 - val_loss: 0.6324 - val_mean_squared_error: 0.6324 - val_mean_absolute_percentage_error: 129.7193
# Epoch 951/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 78.9489 - val_loss: 0.6308 - val_mean_squared_error: 0.6308 - val_mean_absolute_percentage_error: 127.7291
# Epoch 952/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.3394 - val_loss: 0.6305 - val_mean_squared_error: 0.6305 - val_mean_absolute_percentage_error: 127.6566
# Epoch 953/1000
#  - 0s - loss: 0.5557 - mean_squared_error: 0.5557 - mean_absolute_percentage_error: 79.3078 - val_loss: 0.6322 - val_mean_squared_error: 0.6322 - val_mean_absolute_percentage_error: 128.7844
# Epoch 954/1000
#  - 0s - loss: 0.5557 - mean_squared_error: 0.5557 - mean_absolute_percentage_error: 80.0292 - val_loss: 0.6317 - val_mean_squared_error: 0.6317 - val_mean_absolute_percentage_error: 128.4253
# Epoch 955/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.8057 - val_loss: 0.6308 - val_mean_squared_error: 0.6308 - val_mean_absolute_percentage_error: 129.2552
# Epoch 956/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 78.3680 - val_loss: 0.6306 - val_mean_squared_error: 0.6306 - val_mean_absolute_percentage_error: 127.2871
# Epoch 957/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.6934 - val_loss: 0.6321 - val_mean_squared_error: 0.6321 - val_mean_absolute_percentage_error: 127.8208
# Epoch 958/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.6722 - val_loss: 0.6325 - val_mean_squared_error: 0.6325 - val_mean_absolute_percentage_error: 130.1471
# Epoch 959/1000
#  - 0s - loss: 0.5557 - mean_squared_error: 0.5557 - mean_absolute_percentage_error: 79.3440 - val_loss: 0.6319 - val_mean_squared_error: 0.6319 - val_mean_absolute_percentage_error: 128.7914
# Epoch 960/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.0705 - val_loss: 0.6336 - val_mean_squared_error: 0.6336 - val_mean_absolute_percentage_error: 127.2898
# Epoch 961/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.1869 - val_loss: 0.6329 - val_mean_squared_error: 0.6329 - val_mean_absolute_percentage_error: 129.9202
# Epoch 962/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.8137 - val_loss: 0.6317 - val_mean_squared_error: 0.6317 - val_mean_absolute_percentage_error: 128.8354
# Epoch 963/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 78.4448 - val_loss: 0.6311 - val_mean_squared_error: 0.6311 - val_mean_absolute_percentage_error: 127.1774
# Epoch 964/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 78.7294 - val_loss: 0.6320 - val_mean_squared_error: 0.6320 - val_mean_absolute_percentage_error: 127.5123
# Epoch 965/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.0940 - val_loss: 0.6326 - val_mean_squared_error: 0.6326 - val_mean_absolute_percentage_error: 127.9130
# Epoch 966/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.7222 - val_loss: 0.6322 - val_mean_squared_error: 0.6322 - val_mean_absolute_percentage_error: 128.5544
# Epoch 967/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.5392 - val_loss: 0.6327 - val_mean_squared_error: 0.6327 - val_mean_absolute_percentage_error: 127.2578
# Epoch 968/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 79.1325 - val_loss: 0.6319 - val_mean_squared_error: 0.6319 - val_mean_absolute_percentage_error: 127.6793
# Epoch 969/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.9695 - val_loss: 0.6307 - val_mean_squared_error: 0.6307 - val_mean_absolute_percentage_error: 127.7436
# Epoch 970/1000
#  - 0s - loss: 0.5557 - mean_squared_error: 0.5557 - mean_absolute_percentage_error: 79.6936 - val_loss: 0.6309 - val_mean_squared_error: 0.6309 - val_mean_absolute_percentage_error: 128.1645
# Epoch 971/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 80.5646 - val_loss: 0.6323 - val_mean_squared_error: 0.6323 - val_mean_absolute_percentage_error: 128.8573
# Epoch 972/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.7632 - val_loss: 0.6315 - val_mean_squared_error: 0.6315 - val_mean_absolute_percentage_error: 127.5107
# Epoch 973/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.0459 - val_loss: 0.6316 - val_mean_squared_error: 0.6316 - val_mean_absolute_percentage_error: 128.0871
# Epoch 974/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.6024 - val_loss: 0.6318 - val_mean_squared_error: 0.6318 - val_mean_absolute_percentage_error: 128.1864
# Epoch 975/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.3964 - val_loss: 0.6326 - val_mean_squared_error: 0.6326 - val_mean_absolute_percentage_error: 128.9592
# Epoch 976/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 79.4287 - val_loss: 0.6332 - val_mean_squared_error: 0.6332 - val_mean_absolute_percentage_error: 128.5089
# Epoch 977/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 78.8112 - val_loss: 0.6312 - val_mean_squared_error: 0.6312 - val_mean_absolute_percentage_error: 128.5018
# Epoch 978/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.5036 - val_loss: 0.6313 - val_mean_squared_error: 0.6313 - val_mean_absolute_percentage_error: 126.8115
# Epoch 979/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 77.7194 - val_loss: 0.6320 - val_mean_squared_error: 0.6320 - val_mean_absolute_percentage_error: 128.8055
# Epoch 980/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.7579 - val_loss: 0.6320 - val_mean_squared_error: 0.6320 - val_mean_absolute_percentage_error: 130.1627
# Epoch 981/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 79.5113 - val_loss: 0.6325 - val_mean_squared_error: 0.6325 - val_mean_absolute_percentage_error: 129.0954
# Epoch 982/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.1396 - val_loss: 0.6313 - val_mean_squared_error: 0.6313 - val_mean_absolute_percentage_error: 127.4708
# Epoch 983/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.7183 - val_loss: 0.6314 - val_mean_squared_error: 0.6314 - val_mean_absolute_percentage_error: 127.5128
# Epoch 984/1000
#  - 0s - loss: 0.5553 - mean_squared_error: 0.5553 - mean_absolute_percentage_error: 78.5394 - val_loss: 0.6327 - val_mean_squared_error: 0.6327 - val_mean_absolute_percentage_error: 129.4344
# Epoch 985/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.9677 - val_loss: 0.6342 - val_mean_squared_error: 0.6342 - val_mean_absolute_percentage_error: 129.2280
# Epoch 986/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.5182 - val_loss: 0.6323 - val_mean_squared_error: 0.6323 - val_mean_absolute_percentage_error: 127.4927
# Epoch 987/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.4617 - val_loss: 0.6306 - val_mean_squared_error: 0.6306 - val_mean_absolute_percentage_error: 128.0554
# Epoch 988/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.5909 - val_loss: 0.6309 - val_mean_squared_error: 0.6309 - val_mean_absolute_percentage_error: 128.5543
# Epoch 989/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.3337 - val_loss: 0.6325 - val_mean_squared_error: 0.6325 - val_mean_absolute_percentage_error: 128.1262
# Epoch 990/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 80.4063 - val_loss: 0.6316 - val_mean_squared_error: 0.6316 - val_mean_absolute_percentage_error: 128.1168
# Epoch 991/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.9203 - val_loss: 0.6300 - val_mean_squared_error: 0.6300 - val_mean_absolute_percentage_error: 127.6977
# Epoch 992/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.8619 - val_loss: 0.6319 - val_mean_squared_error: 0.6319 - val_mean_absolute_percentage_error: 129.1503
# Epoch 993/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.4880 - val_loss: 0.6319 - val_mean_squared_error: 0.6319 - val_mean_absolute_percentage_error: 127.5150
# Epoch 994/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 78.8352 - val_loss: 0.6309 - val_mean_squared_error: 0.6309 - val_mean_absolute_percentage_error: 128.7543
# Epoch 995/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 79.8706 - val_loss: 0.6309 - val_mean_squared_error: 0.6309 - val_mean_absolute_percentage_error: 129.3875
# Epoch 996/1000
#  - 0s - loss: 0.5556 - mean_squared_error: 0.5556 - mean_absolute_percentage_error: 78.6403 - val_loss: 0.6321 - val_mean_squared_error: 0.6321 - val_mean_absolute_percentage_error: 126.5801
# Epoch 997/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.1425 - val_loss: 0.6328 - val_mean_squared_error: 0.6328 - val_mean_absolute_percentage_error: 128.3840
# Epoch 998/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 78.4342 - val_loss: 0.6320 - val_mean_squared_error: 0.6320 - val_mean_absolute_percentage_error: 128.6271
# Epoch 999/1000
#  - 0s - loss: 0.5555 - mean_squared_error: 0.5555 - mean_absolute_percentage_error: 79.7373 - val_loss: 0.6311 - val_mean_squared_error: 0.6311 - val_mean_absolute_percentage_error: 126.9059
# Epoch 1000/1000
#  - 0s - loss: 0.5554 - mean_squared_error: 0.5554 - mean_absolute_percentage_error: 78.0236 - val_loss: 0.6315 - val_mean_squared_error: 0.6315 - val_mean_absolute_percentage_error: 128.1795

# %%
# summarize history for accuracy
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('mean_squared_error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
